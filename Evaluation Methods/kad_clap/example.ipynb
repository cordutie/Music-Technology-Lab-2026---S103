# %%
from pathlib import Path
from scores_kad import score_kad_clap  # this file

baseline = "/home/esteban/Documents/projects/dev_kad/data/Bees_orig"
generated = "/home/esteban/Documents/projects/dev_kad/data/Bees_gen"

# Use workers=1 to avoid multiprocessing pickling issues inside notebooks
score = score_kad_clap(
    baseline,
    generated,
    out_csv=None,
    device="cuda",       # use "cpu" if no GPU
    workers=1,            # set to 1 for notebook safety
    bandwidth=None,       # None = adaptive bandwidth
    force_emb_encode=False,
    force_stats_calc=False,
)
print("KAD score:", score)
# Out:
# Loading 126 audio files from /home/esteban/Documents/projects/dev_kad/wrapper_similarity scores/Bees_orig...
# ...
# Loading audio files...: 100%|██████████| 126/126 [00:00<00:00, 12772.99it/s]
# Loading 126 audio files from /home/esteban/Documents/projects/dev_kad/wrapper_similarity scores/Bees_gen...
# Loading audio files...: 100%|██████████| 126/126 [00:00<00:00, 7662.61it/s]
# KAD score: 37.970741271972656
