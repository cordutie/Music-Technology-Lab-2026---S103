# %%
from frechet_audio_distance import FrechetAudioDistance

frechet = FrechetAudioDistance(
    model_name="vggish",
    sample_rate=16000,
    use_pca=False, 
    use_activation=False,
    verbose=False
)

path_og = "/home/esteban/Documents/projects/dev_kad/data/Bees_orig"
path_gen = "/home/esteban/Documents/projects/dev_kad/data/Bees_gen"

score = frechet.score(path_og, path_gen, dtype="float32")

print("FAD score:", score)
# Out:
# Using cache found in /home/esteban/.cache/torch/hub/harritaylor_torchvggish_master
# FAD score: 5.864652030356066
